# %%
from nnAudio import Spectrogram
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from helperfunctions import get_dummy_dataset

from sklearn.model_selection import train_test_split
import torch
import torchvision

import os
os.environ['CUDA_VISIBLE_DEVICES']='1'

if torch.cuda.is_available():
    device = "cuda:0"
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
X, Y = get_dummy_dataset()
# Out:
# 100%|██████████| 10925/10925 [00:39<00:00, 279.38it/s]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y.reshape(-1,1), test_size=0.2, random_state=101)

# %%
trainset = torch.utils.data.TensorDataset(torch.tensor(X_train, device='cpu'), torch.tensor(Y_train, device='cpu'))
testset = torch.utils.data.TensorDataset(torch.tensor(X_test, device='cpu'), torch.tensor(Y_test, device='cpu'))

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512)
testloader = torch.utils.data.DataLoader(testset, batch_size=512)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.mel = Spectrogram.MelSpectrogram(n_fft=512, n_mels=32, trainable_mel=True, trainable_STFT=True)
#         torch.nn.init.xavier_uniform_(self.mel.mel_basis)
        self.CNN_layer1 = torch.nn.Conv2d(1,1, kernel_size=(4,4))
        self.CNN_layer2 = torch.nn.Conv2d(1,1, kernel_size=(4,4))
        
        self.regressor = torch.nn.Linear(26*12,1)

    def forward(self, x):
        x = self.mel(x)
        x = self.CNN_layer1(x.unsqueeze(1))
        x = self.CNN_layer2(x)
#         print(x.shape)
        x = x.view(x.data.size()[0], 26*12)
        x = self.regressor(torch.relu(x))
        return torch.sigmoid(x)

# %%
model = Model()
model.cuda()
# Out:
# STFT filter created, time used = 0.0166 seconds
# Mel filter created, time used = 0.0014 seconds
# Model(
#   (mel): MelSpectrogram()
#   (CNN_layer1): Conv2d(1, 1, kernel_size=(4, 4), stride=(1, 1))
#   (CNN_layer2): Conv2d(1, 1, kernel_size=(4, 4), stride=(1, 1))
#   (regressor): Linear(in_features=312, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
loss_function = torch.nn.MSELoss()

# %% [markdown]
# # Visualizing Original Weights

# %%
original_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
original_basis2 = model.mel.mel_basis.cpu().detach().numpy()

# %%
plt.imshow(original_basis2, aspect='auto', origin='lower', cmap='jet')
plt.xlabel('STFT bins', size=16)
plt.ylabel('Mel bins', size=16)
plt.tick_params(labelsize=14)
plt.title('Original Mel Filter Banks',size=18)
# Out:
# Text(0.5, 1.0, 'Original Mel Filter Banks')

# %% [markdown]
# # Traiing Model

# %%
# model.mel.mel_basis.requ

loss_train = []
loss_test = []
print("epoch\ttrain loss\ttest loss")
for e in range(60):
    loss_train_e = 0.0
    loss_test_e = 0.0

    for i, (x, y) in enumerate(trainloader):
        x = x.cuda()
        y = y.cuda()/110240 # Normalizing to labels to [0,1]
        optimizer.zero_grad()
        y_pred = model(x)
        loss = loss_function(y_pred, y)
        loss.backward() # Calculating gradient
        optimizer.step() # Updating paramenters by gradient
        loss_train_e += loss.item()
        print(f"training {i}/{len(trainloader)} batches, loss = {loss.item():.6f}", end = '\r')
    loss_train.append(loss_train_e/len(trainloader))
   
    with torch.no_grad():
        for x, y in testloader:
            x = x.cuda()
            y = y.cuda()/110240
            y_pred = model(x)
            loss = loss_function(y_pred, y)
            loss_test_e +=loss.item()
        loss_test.append(loss_test_e/len(testloader))
        print(' '*100, end='\r')
        print(f"{e}\t{loss_train[-1]:.6f}\t{loss_test[-1]:.6f}")
# Out:
# epoch	train loss	test loss
# 0	0.010455	0.000124
# 1	0.000066	0.000031
# 2	0.000026	0.000016
# 3	0.000016	0.000011
# 4	0.000012	0.000008
# 5	0.000010	0.000007
# 6	0.000008	0.000006
# 7	0.000007	0.000005
# 8	0.000007	0.000004
# 9	0.000006	0.000004
# 10	0.000005	0.000004
# 11	0.000005	0.000003
# 12	0.000005	0.000003
# 13	0.000004	0.000003
# 14	0.000004	0.000004
# 15	0.000004	0.000003
# 16	0.000003	0.000002
# 17	0.000003	0.000002
# 18	0.000003	0.000002
# 19	0.000002	0.000002
# 20	0.000002	0.000002
# 21	0.000003	0.000002
# 22	0.000002	0.000002
# 23	0.000002	0.000002
# 24	0.000002	0.000002
# 25	0.000002	0.000001
# 26	0.000002	0.000001
# 27	0.000002	0.000002
# 28	0.000002	0.000002
# 29	0.000003	0.000002
# 30	0.000002	0.000001
# 31	0.000002	0.000001
# 32	0.000002	0.000001
# 33	0.000001	0.000001
# 34	0.000002	0.000002
# 35	0.000003	0.000002
# 36	0.000002	0.000001
# 37	0.000002	0.000002
# 38	0.000002	0.000001
# 39	0.000001	0.000001
# 40	0.000001	0.000002
# 41	0.000003	0.000002
# 42	0.000002	0.000002
# 43	0.000002	0.000001
# 44	0.000001	0.000001
# 45	0.000001	0.000001
# 46	0.000001	0.000001
# 47	0.000002	0.000001
# 48	0.000001	0.000002
# 49	0.000002	0.000001
# 50	0.000001	0.000001
# 51	0.000001	0.000001
# 52	0.000001	0.000001
# 53	0.000001	0.000002
# 54	0.000001	0.000001
# 55	0.000001	0.000002
# 56	0.000002	0.000001
# 57	0.000001	0.000001
# 58	0.000001	0.000001
# 59	0.000001	0.000001

# %% [markdown]
# # Visualizing Trained Weights

# %%
trained_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
trained_basis2 = model.mel.mel_basis.cpu().detach().numpy()

# %%
plt.imshow(trained_basis2, aspect='auto', origin='lower', cmap='jet')
plt.xlabel('STFT bins', size=16)
plt.ylabel('Mel bins', size=16)
plt.tick_params(labelsize=14)
plt.title('Trained Mel Filter Banks',size=18)
# Out:
# Text(0.5, 1.0, 'Trained Mel Filter Banks')

# %%
np.save('trainable_mel', loss_test)

# %% [markdown]
# # Have a closer look on the STFT basis

# %%
fig, ax = plt.subplots(5,2, figsize=(12,18))
cols = ['Original', 'Trained']
for ax_idx, col in zip(ax[0], cols):
    ax_idx.set_title(col, size=16)

for i in range(5):
    ax[i,0].plot(original_basis[5*i+1])
    ax[i,1].plot(trained_basis[5*i+1])
    ax[i,0].tick_params(labelsize=12)
    ax[i,1].tick_params(labelsize=12)

# %%
plt.imshow(model.mel(x)[0].cpu().detach().numpy(), aspect='auto', origin='lower')
plt.tick_params(labelsize=14)
plt.title('Trained MelSpectrogram',size=18)
# Out:
# Text(0.5, 1.0, 'Trained MelSpectrogram')

# %%
ori_mel = Spectrogram.MelSpectrogram(n_fft=512, n_mels=32, trainable_mel=False, trainable_STFT=False)
# Out:
# STFT filter created, time used = 0.0199 seconds
# Mel filter created, time used = 0.0015 seconds

# %%
plt.imshow(ori_mel(x)[0].cpu().detach().numpy(), aspect='auto', origin='lower')
plt.title('Original MelSpectrogram',size=18)
plt.tick_params(labelsize=14)
