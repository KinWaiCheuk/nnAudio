# %%
from nnAudio import Spectrogram
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from helperfunctions import get_dummy_dataset

from sklearn.model_selection import train_test_split
import torch
import torchvision

import os
os.environ['CUDA_VISIBLE_DEVICES']='1'

if torch.cuda.is_available():
    device = "cuda:0"
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
X, Y = get_dummy_dataset()
# Out:
# 100%|██████████| 10925/10925 [00:39<00:00, 275.43it/s]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y.reshape(-1,1), test_size=0.2, random_state=101)

# %%
trainset = torch.utils.data.TensorDataset(torch.tensor(X_train, device='cpu'), torch.tensor(Y_train, device='cpu'))
testset = torch.utils.data.TensorDataset(torch.tensor(X_test, device='cpu'), torch.tensor(Y_test, device='cpu'))

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512)
testloader = torch.utils.data.DataLoader(testset, batch_size=512)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.mel = Spectrogram.MelSpectrogram(n_fft=512, n_mels=32, trainable_mel=False, trainable_STFT=False)
#         torch.nn.init.xavier_uniform_(self.mel.mel_basis)
        
        self.regressor = torch.nn.Linear(32*18,1)

    def forward(self, x):
        x = self.mel(x)
#         print(x.shape)
        x = x.view(x.data.size()[0], 32*18)
        x = self.regressor(x)
        return torch.sigmoid(x)

# %%
model = Model()
model.cuda()
# Out:
# STFT filter created, time used = 0.0242 seconds
# Mel filter created, time used = 0.0027 seconds
# Model(
#   (mel): MelSpectrogram()
#   (regressor): Linear(in_features=576, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)
loss_function = torch.nn.MSELoss()

# %% [markdown]
# # Visualizing Original Weights

# %%
original_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
original_basis2 = model.mel.mel_basis.cpu().detach().numpy()
plt.imshow(original_basis2, aspect='auto', origin='lower')

# %% [markdown]
# # Traiing Model

# %%
# model.mel.mel_basis.requ

loss_train = []
loss_test = []
print("epoch\ttrain loss\ttest loss")
for e in range(80):
    loss_train_e = 0.0
    loss_test_e = 0.0

    for i, (x, y) in enumerate(trainloader):
        x = x.cuda()
        y = y.cuda()/110240 # Normalizing to labels to [0,1]
        optimizer.zero_grad()
        y_pred = model(x)
        loss = loss_function(y_pred, y)
        loss.backward() # Calculating gradient
        optimizer.step() # Updating paramenters by gradient
        loss_train_e += loss.item()
        print(f"training {i}/{len(trainloader)} batches, loss = {loss.item():.6f}", end = '\r')
    loss_train.append(loss_train_e/len(trainloader))
   
    with torch.no_grad():
        for x, y in testloader:
            x = x.cuda()
            y = y.cuda()/110240
            y_pred = model(x)
            loss = loss_function(y_pred, y)
            loss_test_e +=loss.item()
        loss_test.append(loss_test_e/len(testloader))
        print(' '*100, end='\r')
        print(f"{e}\t{loss_train[-1]:.6f}\t{loss_test[-1]:.6f}")
# Out:
# epoch	train loss	test loss
# 0	0.063024	0.008306
# 1	0.007740	0.007015
# 2	0.007096	0.006527
# 3	0.006237	0.005380
# 4	0.004410	0.004099
# 5	0.004148	0.003963
# 6	0.004011	0.003846
# 7	0.003892	0.003741
# 8	0.003785	0.003646
# 9	0.003689	0.003561
# 10	0.003602	0.003482
# 11	0.003523	0.003410
# 12	0.003449	0.003342
# 13	0.003371	0.003248
# 14	0.003287	0.003190
# 15	0.003231	0.003139
# 16	0.003178	0.003091
# 17	0.003129	0.003045
# 18	0.003083	0.003003
# 19	0.003040	0.002963
# 20	0.002999	0.002925
# 21	0.002960	0.002890
# 22	0.002923	0.002855
# 23	0.002883	0.002821
# 24	0.002851	0.002795
# 25	0.002823	0.002771
# 26	0.002798	0.002749
# 27	0.002774	0.002728
# 28	0.002751	0.002708
# 29	0.002728	0.002688
# 30	0.002699	0.002627
# 31	0.002618	0.002581
# 32	0.002582	0.002523
# 33	0.002535	0.002503
# 34	0.002515	0.002486
# 35	0.002497	0.002471
# 36	0.002481	0.002457
# 37	0.002466	0.002445
# 38	0.002453	0.002433
# 39	0.002440	0.002422
# 40	0.002428	0.002412
# 41	0.002417	0.002402
# 42	0.002406	0.002392
# 43	0.002396	0.002384
# 44	0.002386	0.002375
# 45	0.002376	0.002367
# 46	0.002367	0.002359
# 47	0.002359	0.002352
# 48	0.002351	0.002345
# 49	0.002343	0.002338
# 50	0.002336	0.002333
# 51	0.002329	0.002327
# 52	0.002322	0.002322
# 53	0.002316	0.002318
# 54	0.002310	0.002313
# 55	0.002305	0.002309
# 56	0.002300	0.002304
# 57	0.002295	0.002300
# 58	0.002290	0.002297
# 59	0.002286	0.002293
# 60	0.002282	0.002290
# 61	0.002278	0.002287
# 62	0.002274	0.002285
# 63	0.002271	0.002282
# 64	0.002268	0.002280
# 65	0.002265	0.002278
# 66	0.002262	0.002276
# 67	0.002259	0.002274
# 68	0.002256	0.002272
# 69	0.002254	0.002270
# 70	0.002252	0.002269
# 71	0.002250	0.002267
# 72	0.002248	0.002266
# 73	0.002246	0.002264
# 74	0.002244	0.002263
# 75	0.002242	0.002262
# 76	0.002241	0.002261
# 77	0.002240	0.002260
# 78	0.002238	0.002259
# 79	0.002237	0.002258

# %% [markdown]
# # Visualizing Trained Weights

# %%
trained_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
trained_basis2 = model.mel.mel_basis.cpu().detach().numpy()
plt.imshow(trained_basis2, aspect='auto', origin='lower')

# %%
np.save('nontrainable_mel_lin', loss_test)

# %% [markdown]
# # Have a closer look on the STFT basis

# %%
fig, ax = plt.subplots(5,2, figsize=(12,18))
cols = ['Original', 'Trained']
for ax_idx, col in zip(ax[0], cols):
    ax_idx.set_title(col, size=16)

for i in range(5):
    ax[i,0].plot(original_basis[5*i+1])
    ax[i,1].plot(trained_basis[5*i+1])
    ax[i,0].tick_params(labelsize=12)
    ax[i,1].tick_params(labelsize=12)
