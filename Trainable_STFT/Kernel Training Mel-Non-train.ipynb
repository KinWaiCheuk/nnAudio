# %%
from nnAudio import Spectrogram
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from helperfunctions import get_dummy_dataset

from sklearn.model_selection import train_test_split
import torch
import torchvision

import os
os.environ['CUDA_VISIBLE_DEVICES']='1'

if torch.cuda.is_available():
    device = "cuda:0"
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
X, Y = get_dummy_dataset()
# Out:
# 100%|██████████| 10925/10925 [00:39<00:00, 277.43it/s]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y.reshape(-1,1), test_size=0.2, random_state=101)

# %%
trainset = torch.utils.data.TensorDataset(torch.tensor(X_train, device='cpu'), torch.tensor(Y_train, device='cpu'))
testset = torch.utils.data.TensorDataset(torch.tensor(X_test, device='cpu'), torch.tensor(Y_test, device='cpu'))

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512)
testloader = torch.utils.data.DataLoader(testset, batch_size=512)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.mel = Spectrogram.MelSpectrogram(n_fft=1024, n_mels=64, trainable_mel=False, trainable_STFT=False)
#         torch.nn.init.xavier_uniform_(self.mel.mel_basis)
        self.CNN_layer1 = torch.nn.Conv2d(1,1, kernel_size=(4,4))
        self.CNN_layer2 = torch.nn.Conv2d(1,1, kernel_size=(4,4))
        
        self.regressor = torch.nn.Linear(58*12,1)

    def forward(self, x):
        x = self.mel(x)
        x = self.CNN_layer1(x.unsqueeze(1))
        x = self.CNN_layer2(x)
#         print(x.shape)
        x = x.view(x.data.size()[0], 58*12)
        x = self.regressor(torch.relu(x))
        return torch.sigmoid(x)

# %%
model = Model()
model.cuda()
# Out:
# STFT filter created, time used = 6.9713 seconds
# Mel filter created, time used = 0.0024 seconds
# Model(
#   (mel): MelSpectrogram()
#   (CNN_layer1): Conv2d(1, 1, kernel_size=(4, 4), stride=(1, 1))
#   (CNN_layer2): Conv2d(1, 1, kernel_size=(4, 4), stride=(1, 1))
#   (regressor): Linear(in_features=696, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.8e-4)
loss_function = torch.nn.MSELoss()

# %% [markdown]
# # Visualizing Original Weights

# %%
original_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
original_basis2 = model.mel.mel_basis.cpu().detach().numpy()
plt.imshow(original_basis2, aspect='auto', origin='lower')

# %% [markdown]
# # Traiing Model

# %%
# model.mel.mel_basis.requ

loss_train = []
loss_test = []
print("epoch\ttrain loss\ttest loss")
for e in range(60):
    loss_train_e = 0.0
    loss_test_e = 0.0

    for i, (x, y) in enumerate(trainloader):
        x = x.cuda()
        y = y.cuda()/110240 # Normalizing to labels to [0,1]
        optimizer.zero_grad()
        y_pred = model(x)
        loss = loss_function(y_pred, y)
        loss.backward() # Calculating gradient
        optimizer.step() # Updating paramenters by gradient
        loss_train_e += loss.item()
        print(f"training {i}/{len(trainloader)} batches, loss = {loss.item():.6f}", end = '\r')
    loss_train.append(loss_train_e/len(trainloader))
   
    with torch.no_grad():
        for x, y in testloader:
            x = x.cuda()
            y = y.cuda()/110240
            y_pred = model(x)
            loss = loss_function(y_pred, y)
            loss_test_e +=loss.item()
        loss_test.append(loss_test_e/len(testloader))
        print(' '*100, end='\r')
        print(f"{e}\t{loss_train[-1]:.6f}\t{loss_test[-1]:.6f}")
# Out:
# epoch	train loss	test loss
# 0	0.054471	0.032042
# 1	0.021002	0.008533
# 2	0.006107	0.004356
# 3	0.004011	0.003480
# 4	0.003336	0.003006
# 5	0.002925	0.002681
# 6	0.002603	0.002347
# 7	0.002264	0.002038
# 8	0.001935	0.001715
# 9	0.001717	0.001579
# 10	0.001591	0.001462
# 11	0.001479	0.001353
# 12	0.001355	0.001246
# 13	0.001270	0.001175
# 14	0.001204	0.001116
# 15	0.001149	0.001065
# 16	0.001100	0.001021
# 17	0.001056	0.000980
# 18	0.001015	0.000943
# 19	0.000966	0.000889
# 20	0.000922	0.000857
# 21	0.000891	0.000829
# 22	0.000861	0.000799
# 23	0.000822	0.000766
# 24	0.000795	0.000744
# 25	0.000772	0.000722
# 26	0.000753	0.000702
# 27	0.000728	0.000674
# 28	0.000694	0.000646
# 29	0.000675	0.000635
# 30	0.000666	0.000623
# 31	0.000652	0.000609
# 32	0.000633	0.000603
# 33	0.000621	0.000595
# 34	0.000612	0.000585
# 35	0.000600	0.000572
# 36	0.000582	0.000561
# 37	0.000579	0.000552
# 38	0.000567	0.000549
# 39	0.000560	0.000541
# 40	0.000553	0.000537
# 41	0.000546	0.000529
# 42	0.000542	0.000523
# 43	0.000535	0.000519
# 44	0.000529	0.000513
# 45	0.000524	0.000509
# 46	0.000521	0.000506
# 47	0.000521	0.000503
# 48	0.000513	0.000507
# 49	0.000511	0.000500
# 50	0.000507	0.000498
# 51	0.000507	0.000497
# 52	0.000502	0.000494
# 53	0.000501	0.000486
# 54	0.000498	0.000475
# 55	0.000492	0.000480
# 56	0.000493	0.000494
# 57	0.000499	0.000469
# 58	0.000482	0.000471
# 59	0.000482	0.000470

# %% [markdown]
# # Visualizing Trained Weights

# %%
trained_basis = model.mel.wsin.cpu().detach().numpy().squeeze(1)
trained_basis2 = model.mel.mel_basis.cpu().detach().numpy()
plt.imshow(trained_basis2, aspect='auto', origin='lower')

# %%
np.save('nontrainable_mel', loss_test)

# %% [markdown]
# # Have a closer look on the STFT basis

# %%
fig, ax = plt.subplots(5,2, figsize=(12,18))
cols = ['Original', 'Trained']
for ax_idx, col in zip(ax[0], cols):
    ax_idx.set_title(col, size=16)

for i in range(5):
    ax[i,0].plot(original_basis[5*i+1])
    ax[i,1].plot(trained_basis[5*i+1])
    ax[i,0].tick_params(labelsize=12)
    ax[i,1].tick_params(labelsize=12)
